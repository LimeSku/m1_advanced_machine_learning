# %%
import tensorflow as tf
import keras
import numpy as np

print("NumPy version:", np.__version__)
print("TensorFlow version:", tf.__version__)
print("Keras version:", keras.__version__)

from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import SGD
# Out:
# NumPy version: 2.0.2
# TensorFlow version: 2.18.0
# Keras version: 3.8.0

# %% [markdown]
# # XOR

# %%
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [0]])

model = Sequential()
model.add(Dense(8, input_dim=2))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

sgd = SGD(learning_rate=0.1)
model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

model.fit(X, y, batch_size=1, epochs=50)
predictions = model.predict(X)

loss, accuracy = model.evaluate(X, y)

for i, prediction in enumerate(predictions):
    print(f"Input: {X[i]}, Prediction: {prediction[0]}, Result: {round(prediction[0])}")


print(f"Accuracy: {accuracy}")
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7333 - loss: 0.6060
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4333 - loss: 0.8221
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7333 - loss: 0.6494
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5667 - loss: 0.7101
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7333 - loss: 0.6795
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4333 - loss: 0.7250
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4333 - loss: 0.7520
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7333 - loss: 0.6535
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6333 - loss: 0.6999
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3667 - loss: 0.7408
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3667 - loss: 0.7265
# Epoch 12/50
# ...

# %%
from keras.callbacks import TensorBoard
import datetime

# Create a TensorBoard callback
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# Train the model with the TensorBoard callback
model.fit(X, y, batch_size=1, epochs=50, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0268
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0166
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0142
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0177
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0134
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0232
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0166
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0227
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0239
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0148
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0161
# Epoch 12/50
# ...

# %% [markdown]
# # AND

# %%
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [0], [0], [1]])

model = Sequential()
model.add(Dense(8, input_dim=2))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

sgd = SGD(learning_rate=0.1)
model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

model.fit(X, y, batch_size=1, epochs=50)
predictions = model.predict(X)

loss, accuracy = model.evaluate(X, y)

for i, prediction in enumerate(predictions):
    print(f"Input: {X[i]}, Prediction: {prediction[0]}, Result: {round(prediction[0])}")


print(f"Accuracy: {accuracy}")
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5667 - loss: 0.7158
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7333 - loss: 0.7562
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9000 - loss: 0.5145
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8333 - loss: 0.5678
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5333 - loss: 0.7730
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7333 - loss: 0.5846
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5333 - loss: 0.7182
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5333 - loss: 0.7011
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7333 - loss: 0.5256
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5333 - loss: 0.6587
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9000 - loss: 0.3535
# Epoch 12/50
# ...

# %% [markdown]
# # OR

# %%
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [1]])

model = Sequential()
model.add(Dense(8, input_dim=2))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

sgd = SGD(learning_rate=0.1)
model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

model.fit(X, y, batch_size=1, epochs=50)
predictions = model.predict(X)

loss, accuracy = model.evaluate(X, y)

for i, prediction in enumerate(predictions):
    print(f"Input: {X[i]}, Prediction: {prediction[0]}, Result: {round(prediction[0])}")


print(f"Accuracy: {accuracy}")
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1667 - loss: 0.7766
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3667 - loss: 0.6593
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5667 - loss: 0.5007
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8333 - loss: 0.3671
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9000 - loss: 0.3973
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7333 - loss: 0.4295
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8333 - loss: 0.3544
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7333 - loss: 0.3655
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7333 - loss: 0.3805
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8333 - loss: 0.3081
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8333 - loss: 0.3174
# Epoch 12/50
# ...

# %% [markdown]
# # BONUS : ALL 3 IN 1

# %%
def train_and_evaluate(epochs=50):
	datasets = {
		"XOR": (X_xor, y_xor),
		"AND": (X_and, y_and),
		"OR": (X_or, y_or)
	}
	
	for name, (X, y) in datasets.items():
		print(f"\n{name}")
		model = Sequential()
		model.add(Dense(8, input_dim=2))
		model.add(Activation('relu'))
		model.add(Dense(1))
		model.add(Activation('sigmoid'))

		sgd = SGD(learning_rate=0.1)
		model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

		model.fit(X, y, batch_size=1, epochs=epochs, verbose=0)
		predictions = model.predict(X)

		loss, accuracy = model.evaluate(X, y)

		for i, prediction in enumerate(predictions):
			print(f"Input: {X[i]}, Prediction: {prediction[0]}, Result: {round(prediction[0])}")

		print(f"Accuracy: {accuracy}")

# Train and evaluate the model on all datasets
train_and_evaluate()
# Out:
# XOR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 0.2814
# Input: [0 0], Prediction: 0.3566719889640808, Result: 0
# Input: [0 1], Prediction: 0.8465597629547119, Result: 1
# Input: [1 0], Prediction: 0.7596226334571838, Result: 1
# Input: [1 1], Prediction: 0.2155729979276657, Result: 0
# Accuracy: 1.0
#
# AND
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0899
# Input: [0 0], Prediction: 0.025053121149539948, Result: 0
# Input: [0 1], Prediction: 0.0903683453798294, Result: 0
# Input: [1 0], Prediction: 0.09170253574848175, Result: 0
# Input: [1 1], Prediction: 0.8664012551307678, Result: 1
# Accuracy: 1.0
#
# OR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.7500 - loss: 0.2440
# Input: [0 0], Prediction: 0.5151182413101196, Result: 1
# Input: [0 1], Prediction: 0.8199772238731384, Result: 1
# ...
